# %%
from mlblocks.discovery import find_pipelines

# %%
# Load the dataset from a dataset on the s3 bucket, or in this example the local file path
from pyteller.data import load_data
current_data = load_data('AL_Weather_current')

# Specify pipeline and hyperparamters if any
pipeline = 'pyteller/pipelines/pyteller/persistence/persistence.json'

# Make instance of Pyteller, specifying where to make the prediction and the column names
from pyteller.core import Pyteller
pyteller = Pyteller(
    pipeline=pipeline,
    pred_length=10,
    offset=5,
    timestamp_col='valid',
    target_signal='tmpf',
    # static_variables=None,
    entity_col='station',
    # entities='8A0',
)

# Fit the data to the pipeline.
train = pyteller.fit(current_data)

# Load the input_data
input_data = load_data('pyteller/data/AL_Weather_input.csv')

# forecast and evaluatee

output = pyteller.forecast(data=input_data)
scores = pyteller.evaluate(test_data=output['actual'], forecast=output['forecast'], metrics=['MAPE','sMAPE'])

# %%
output
# Out:
# {'forecast': entity                 4A6   8A0
#  2016-02-05 02:55:00  39.20  37.4
#  2016-02-05 03:15:00  38.30  37.4
#  2016-02-05 03:35:00  38.00  37.4
#  2016-02-05 03:55:00  37.40  37.4
#  2016-02-05 04:15:00  37.04  37.4
#  ...                    ...   ...
#  2016-02-12 14:55:00  35.60  33.8
#  2016-02-12 15:15:00  35.60  33.8
#  2016-02-12 15:35:00  35.60  33.8
#  2016-02-12 15:55:00  35.60  33.8
#  2016-02-12 16:15:00  35.60  33.8
#
#  [545 rows x 2 columns],
#  'actual': entity                4A6   8A0
#  timestamp
#  2016-02-05 02:55:00  37.4  35.6
#  2016-02-05 03:15:00  37.4  35.6
#  2016-02-05 03:35:00  35.6  35.6
#  2016-02-05 03:55:00  35.6  35.6
#  2016-02-05 04:15:00  35.6  35.6
#  ...                   ...   ...
#  2016-02-12 14:55:00  41.0  42.8
#  2016-02-12 15:15:00  42.8  44.6
#  2016-02-12 15:35:00  44.6  46.4
#  2016-02-12 15:55:00  46.4  48.2
#  2016-02-12 16:15:00  48.2  50.0
#
#  [545 rows x 2 columns]}

# %%
scores
# Out:
# entity        4A6        8A0
# sMAPE   13.318160  11.383547
# MAPE    13.184471  11.180610

# %%
pyteller.plot(output)
